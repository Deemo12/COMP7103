# %%
import sys
from pathlib import Path
import subprocess
import os
import gc
from glob import glob

import numpy as np
import pandas as pd
import polars as pl
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

ROOT = '/kaggle/input/home-credit-credit-risk-model-stability'

from sklearn.model_selection import TimeSeriesSplit, GroupKFold, StratifiedGroupKFold
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.metrics import roc_auc_score
import lightgbm as lgb

from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import KNNImputer

# %%
class Pipeline:

    def set_table_dtypes(df):
        for col in df.columns:
            if col in ["case_id", "WEEK_NUM", "num_group1", "num_group2"]:
                df = df.with_columns(pl.col(col).cast(pl.Int64))
            elif col in ["date_decision"]:
                df = df.with_columns(pl.col(col).cast(pl.Date))
            elif col[-1] in ("P", "A"):
                df = df.with_columns(pl.col(col).cast(pl.Float64))
            elif col[-1] in ("M",):
                df = df.with_columns(pl.col(col).cast(pl.String))
            elif col[-1] in ("D",):
                df = df.with_columns(pl.col(col).cast(pl.Date))
        return df

    def handle_dates(df):
        for col in df.columns:
            if col[-1] in ("D",):
                df = df.with_columns(pl.col(col) - pl.col("date_decision"))  #!!?
                df = df.with_columns(pl.col(col).dt.total_days()) # t - t-1
        df = df.drop("date_decision", "MONTH")
        return df

    def filter_cols(df):
        for col in df.columns:
            if col not in ["target", "case_id", "WEEK_NUM"]:
                isnull = df[col].is_null().mean()
                if isnull > 0.7:
                    df = df.drop(col)
        
        for col in df.columns:
            if (col not in ["target", "case_id", "WEEK_NUM"]) & (df[col].dtype == pl.String):
                freq = df[col].n_unique()
                if (freq == 1) | (freq > 200):
                    df = df.drop(col)
        
        return df


class Aggregator:
    
    def num_expr(df):
        cols = [col for col in df.columns if col[-1] in ("P", "A")]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]
        
        expr_last = [pl.last(col).alias(f"last_{col}") for col in cols]
        
        expr_mean = [pl.mean(col).alias(f"mean_{col}") for col in cols]
        return expr_max +expr_last+expr_mean
    
    def date_expr(df):
        cols = [col for col in df.columns if col[-1] in ("D")]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        expr_last = [pl.last(col).alias(f"last_{col}") for col in cols]

        expr_mean = [pl.mean(col).alias(f"mean_{col}") for col in cols]
        return  expr_max +expr_last+expr_mean
    
    def str_expr(df):
        cols = [col for col in df.columns if col[-1] in ("M",)]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        expr_last = [pl.last(col).alias(f"last_{col}") for col in cols]

        return  expr_max +expr_last
    
    def other_expr(df):
        cols = [col for col in df.columns if col[-1] in ("T", "L")]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols]

        expr_last = [pl.last(col).alias(f"last_{col}") for col in cols]

        return  expr_max +expr_last
    
    def count_expr(df):
        cols = [col for col in df.columns if "num_group" in col]
        expr_max = [pl.max(col).alias(f"max_{col}") for col in cols] 
        expr_last = [pl.last(col).alias(f"last_{col}") for col in cols]
        
        return  expr_max +expr_last
    
    def get_exprs(df):
        exprs = Aggregator.num_expr(df) + \
                Aggregator.date_expr(df) + \
                Aggregator.str_expr(df) + \
                Aggregator.other_expr(df) + \
                Aggregator.count_expr(df)

        return exprs

def read_file(path, depth=None):
    df = pl.read_parquet(path)
    df = df.pipe(Pipeline.set_table_dtypes)
    if depth in [1,2]:
        df = df.group_by("case_id").agg(Aggregator.get_exprs(df)) 
    return df

def read_files(regex_path, depth=None):
    chunks = []
    
    for path in glob(str(regex_path)):
        df = pl.read_parquet(path)
        df = df.pipe(Pipeline.set_table_dtypes)
        if depth in [1, 2]:
            df = df.group_by("case_id").agg(Aggregator.get_exprs(df))
        chunks.append(df)
    
    df = pl.concat(chunks, how="vertical_relaxed")
    df = df.unique(subset=["case_id"])
    return df

def feature_eng(df_base, depth_0, depth_1, depth_2):
    df_base = (
        df_base
        .with_columns(
            month_decision = pl.col("date_decision").dt.month(),
            weekday_decision = pl.col("date_decision").dt.weekday(),
        )
    )
    for i, df in enumerate(depth_0 + depth_1 + depth_2):
        df_base = df_base.join(df, how="left", on="case_id", suffix=f"_{i}")
    df_base = df_base.pipe(Pipeline.handle_dates)
    return df_base

def to_pandas(df_data, cat_cols=None):
    df_data = df_data.to_pandas()
    if cat_cols is None:
        cat_cols = list(df_data.select_dtypes("object").columns)
    df_data[cat_cols] = df_data[cat_cols].astype("category")
    return df_data, cat_cols

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        if str(col_type)=="category":
            continue
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            continue
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
ROOT            = Path("/kaggle/input/home-credit-credit-risk-model-stability")

TRAIN_DIR       = ROOT / "parquet_files" / "train"
TEST_DIR        = ROOT / "parquet_files" / "test"

# %%
# %%time
data_store = {
    "df_base": read_file(TRAIN_DIR / "train_base.parquet"),
    "depth_0": [
        read_file(TRAIN_DIR / "train_static_cb_0.parquet"),
        read_files(TRAIN_DIR / "train_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TRAIN_DIR / "train_applprev_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_a_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_tax_registry_c_1.parquet", 1),
        read_files(TRAIN_DIR / "train_credit_bureau_a_1_*.parquet", 1),
        read_file(TRAIN_DIR / "train_credit_bureau_b_1.parquet", 1),
        read_file(TRAIN_DIR / "train_other_1.parquet", 1),
        read_file(TRAIN_DIR / "train_person_1.parquet", 1),
        read_file(TRAIN_DIR / "train_deposit_1.parquet", 1),
        read_file(TRAIN_DIR / "train_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TRAIN_DIR / "train_credit_bureau_b_2.parquet", 2),
        read_files(TRAIN_DIR / "train_credit_bureau_a_2_*.parquet", 2),
        read_file(TRAIN_DIR / "train_applprev_2.parquet", 2),
        read_file(TRAIN_DIR / "train_person_2.parquet", 2)
    ]
}
# Out:
# CPU times: user 4min 32s, sys: 1min 35s, total: 6min 7s
# Wall time: 2min 9s

# %%
# %%time
df_train = feature_eng(**data_store)
print("train data shape:\t", df_train.shape)
del data_store
gc.collect()
df_train = df_train.pipe(Pipeline.filter_cols)
df_train, cat_cols = to_pandas(df_train)
df_train = reduce_mem_usage(df_train)
print("train data shape:\t", df_train.shape)
nums=df_train.select_dtypes(exclude='category').columns
from itertools import combinations, permutations
#df_train=df_train[nums]
nans_df = df_train[nums].isna()
nans_groups={}
for col in nums:
    cur_group = nans_df[col].sum()
    try:
        nans_groups[cur_group].append(col)
    except:
        nans_groups[cur_group]=[col]
del nans_df; x=gc.collect()

def reduce_group(grps):
    use = []
    for g in grps:
        mx = 0; vx = g[0]
        for gg in g:
            n = df_train[gg].nunique()
            if n>mx:
                mx = n
                vx = gg
            #print(str(gg)+'-'+str(n),', ',end='')
        use.append(vx)
        #print()
    print('Use these',use)
    return use

def group_columns_by_correlation(matrix, threshold=0.8):
    # 计算列之间的相关性
    correlation_matrix = matrix.corr()

    # 分组列
    groups = []
    remaining_cols = list(matrix.columns)
    while remaining_cols:
        col = remaining_cols.pop(0)
        group = [col]
        correlated_cols = [col]
        for c in remaining_cols:
            if correlation_matrix.loc[col, c] >= threshold:
                group.append(c)
                correlated_cols.append(c)
        groups.append(group)
        remaining_cols = [c for c in remaining_cols if c not in correlated_cols]
    
    return groups

uses=[]
for k,v in nans_groups.items():
    if len(v)>1:
            Vs = nans_groups[k]
            #cross_features=list(combinations(Vs, 2))
            #make_corr(Vs)
            grps= group_columns_by_correlation(df_train[Vs], threshold=0.8)
            use=reduce_group(grps)
            uses=uses+use
            #make_corr(use)
    else:
        uses=uses+v
    print('####### NAN count =',k)
print(len(uses))
uses=uses+list(df_train.select_dtypes(include='category').columns)
print(len(uses))
df_train=df_train[uses]
# Out:
# train data shape:	 (1526659, 861)
# Memory usage of dataframe is 4322.75 MB
# Memory usage after optimization is: 1528.81 MB
# Decreased by 64.6%
# train data shape:	 (1526659, 472)
# Use these ['case_id', 'WEEK_NUM', 'target', 'month_decision', 'weekday_decision', 'credamount_770A', 'applicationcnt_361L', 'applications30d_658L', 'applicationscnt_1086L', 'applicationscnt_464L', 'applicationscnt_867L', 'clientscnt_1022L', 'clientscnt_100L', 'clientscnt_1071L', 'clientscnt_1130L', 'clientscnt_157L', 'clientscnt_257L', 'clientscnt_304L', 'clientscnt_360L', 'clientscnt_493L', 'clientscnt_533L', 'clientscnt_887L', 'clientscnt_946L', 'deferredmnthsnum_166L', 'disbursedcredamount_1113A', 'downpmt_116A', 'homephncnt_628L', 'isbidproduct_1095L', 'mobilephncnt_593L', 'numactivecreds_622L', 'numactivecredschannel_414L', 'numactiverelcontr_750L', 'numcontrs3months_479L', 'numnotactivated_1143L', 'numpmtchanneldd_318L', 'numrejects9m_859L', 'sellerplacecnt_915L', 'max_mainoccupationinc_384A', 'max_birth_259D', 'max_num_group1_9']
# ####### NAN count = 0
# ####### NAN count = 918788
# Use these ['dateofbirth_337D', 'days180_256L', 'days30_165L', 'days360_512L', 'firstquarter_103L', 'fourthquarter_440L', 'secondquarter_766L', 'thirdquarter_1082L', 'max_debtoutstand_525A', 'max_debtoverdue_47A', 'max_refreshdate_3813885D', 'mean_refreshdate_3813885D']
# ####### NAN count = 140968
# Use these ['pmtscount_423L', 'pmtssum_45A']
# ####### NAN count = 954021
# ####### NAN count = 806659
# ####### NAN count = 866332
# ####### NAN count = 418178
# Use these ['amtinstpaidbefduel24m_4187115A', 'numinstlswithdpd5_4187116L']
# ####### NAN count = 561124
# Use these ['annuitynextmonth_57A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'numinstls_657L', 'totalsettled_863A']
# ####### NAN count = 4
# Use these ['mindbddpdlast24m_3658935P']
# ####### NAN count = 613202
# ####### NAN count = 948244
# Use these ['mindbdtollast24m_4525191P']
# ####### NAN count = 972827
# ####### NAN count = 467175
# Use these ['avginstallast24m_3658937A', 'maxinstallast24m_3658928A']
# ####### NAN count = 624875
# ####### NAN count = 757006
# ####### NAN count = 841181
# ####### NAN count = 1026987
# ####### NAN count = 455190
# ####### NAN count = 460822
# Use these ['commnoinclast6m_3546845L', 'maxdpdfrom6mto36m_3546853P']
# ####### NAN count = 343375
# ####### NAN count = 833735
# ####### NAN count = 887659
# Use these ['daysoverduetolerancedd_3976961L', 'numinsttopaygr_769L']
# ####### NAN count = 452594
# ####### NAN count = 977119
# Use these ['eir_270L']
# ####### NAN count = 190833
# ####### NAN count = 859214
# ####### NAN count = 482103
# ####### NAN count = 453587
# Use these ['lastapplicationdate_877D', 'mean_creationdate_885D', 'max_num_group1', 'last_num_group1', 'max_num_group2_14', 'last_num_group2_14']
# ####### NAN count = 305137
# Use these ['lastapprcredamount_781A', 'lastapprdate_640D']
# ####### NAN count = 442041
# ####### NAN count = 977975
# Use these ['lastrejectcredamount_222A', 'lastrejectdate_50D']
# ####### NAN count = 769046
# ####### NAN count = 511255
# Use these ['mastercontrelectronic_519L', 'mastercontrexist_109L', 'maxannuity_159A', 'maxdebt4_972A', 'maxdpdlast24m_143P', 'maxdpdlast3m_392P', 'maxdpdtolerance_374P']
# ####### NAN count = 306019
# ####### NAN count = 960953
# ####### NAN count = 705504
# ####### NAN count = 876276
# ####### NAN count = 826000
# ####### NAN count = 829402
# ####### NAN count = 1032856
# ####### NAN count = 766958
# Use these ['numinstpaidearly_338L', 'numinstpaidearly5d_1087L', 'numinstpaidlate1d_3546852L']
# ####### NAN count = 452593
# ####### NAN count = 455081
# Use these ['numinstlsallpaid_934L']
# ####### NAN count = 445669
# Use these ['numinstlswithdpd10_728L', 'numinstlswithoutdpd_562L']
# ####### NAN count = 456495
# Use these ['numinstpaid_4499208L']
# ####### NAN count = 847191
# ####### NAN count = 446983
# Use these ['numinstregularpaidest_4493210L', 'numinstpaidearly5dest_4493211L', 'sumoutstandtotalest_4493215A']
# ####### NAN count = 840646
# ####### NAN count = 669186
# ####### NAN count = 455612
# Use these ['pctinstlsallpaidearl3d_427L', 'pctinstlsallpaidlate1d_3546856L']
# ####### NAN count = 458738
# ####### NAN count = 461362
# ####### NAN count = 459827
# ####### NAN count = 460079
# ####### NAN count = 44954
# ####### NAN count = 78526
# ####### NAN count = 131888
# ####### NAN count = 181122
# ####### NAN count = 223240
# ####### NAN count = 445320
# ####### NAN count = 3
# Use these ['mean_actualdpd_943P']
# ####### NAN count = 305154
# Use these ['max_annuity_853A', 'mean_annuity_853A']
# ####### NAN count = 308739
# Use these ['max_credacc_credlmt_575A', 'max_credamount_590A', 'max_downpmt_134A', 'mean_credacc_credlmt_575A', 'mean_credamount_590A', 'mean_downpmt_134A']
# ####### NAN count = 307441
# Use these ['max_currdebt_94A', 'mean_currdebt_94A']
# ####### NAN count = 419006
# Use these ['max_mainoccupationinc_437A', 'mean_mainoccupationinc_437A']
# ####### NAN count = 306361
# Use these ['mean_maxdpdtolerance_577P']
# ####### NAN count = 450969
# Use these ['max_outstandingdebt_522A', 'mean_outstandingdebt_522A']
# ####### NAN count = 420383
# ####### NAN count = 307551
# ####### NAN count = 477657
# ####### NAN count = 433335
# Use these ['last_credamount_590A', 'last_downpmt_134A']
# ####### NAN count = 438219
# ####### NAN count = 824731
# ####### NAN count = 312491
# ####### NAN count = 899665
# ####### NAN count = 827764
# Use these ['max_approvaldate_319D', 'mean_approvaldate_319D']
# ####### NAN count = 442999
# Use these ['max_dateactivated_425D', 'mean_dateactivated_425D']
# ####### NAN count = 454678
# Use these ['max_dtlastpmt_581D', 'mean_dtlastpmt_581D']
# ####### NAN count = 703840
# Use these ['max_dtlastpmtallstes_3545839D', 'mean_dtlastpmtallstes_3545839D']
# ####### NAN count = 548987
# Use these ['max_employedfrom_700D']
# ####### NAN count = 559169
# Use these ['max_firstnonzeroinstldate_307D', 'mean_firstnonzeroinstldate_307D']
# ####### NAN count = 334873
# ####### NAN count = 891021
# ####### NAN count = 305203
# ####### NAN count = 920818
# ####### NAN count = 1016761
# ####### NAN count = 1050001
# ####### NAN count = 485683
# ####### NAN count = 961606
# ####### NAN count = 552766
# Use these ['max_pmtnum_8L']
# ####### NAN count = 321446
# Use these ['last_pmtnum_8L']
# ####### NAN count = 482174
# Use these ['max_pmtamount_36A', 'last_pmtamount_36A', 'max_processingdate_168D', 'last_processingdate_168D', 'max_num_group1_5']
# ####### NAN count = 1044394
# Use these ['mean_credlmt_230A']
# ####### NAN count = 1036944
# Use these ['mean_credlmt_935A']
# ####### NAN count = 603001
# Use these ['mean_pmts_dpd_1073P', 'max_dpdmaxdatemonth_89T', 'max_dpdmaxdateyear_596T']
# ####### NAN count = 263166
# Use these ['max_pmts_dpd_303P', 'mean_dpdmax_757P', 'max_dpdmaxdatemonth_442T', 'max_dpdmaxdateyear_896T', 'mean_pmts_dpd_303P']
# ####### NAN count = 514070
# Use these ['mean_instlamount_768A']
# ####### NAN count = 606920
# Use these ['mean_monthlyinstlamount_332A']
# ####### NAN count = 263233
# Use these ['max_monthlyinstlamount_674A', 'mean_monthlyinstlamount_674A']
# ####### NAN count = 517511
# Use these ['mean_outstandingamount_354A']
# ####### NAN count = 545885
# Use these ['mean_outstandingamount_362A']
# ####### NAN count = 636453
# Use these ['mean_overdueamount_31A']
# ####### NAN count = 512650
# Use these ['mean_overdueamount_659A', 'max_numberofoverdueinstls_725L']
# ####### NAN count = 263171
# Use these ['mean_overdueamountmax2_14A', 'mean_totaloutstanddebtvalue_39A', 'mean_dateofcredend_289D', 'mean_dateofcredstart_739D', 'max_lastupdate_1112D', 'mean_lastupdate_1112D', 'max_numberofcontrsvalue_258L', 'max_numberofoverdueinstlmax_1039L', 'max_overdueamountmaxdatemonth_365T', 'max_overdueamountmaxdateyear_2T', 'mean_pmts_overdue_1140A', 'max_pmts_month_158T', 'max_pmts_year_1139T']
# ####### NAN count = 262653
# Use these ['mean_overdueamountmax2_398A', 'max_dateofcredend_353D', 'max_dateofcredstart_181D', 'mean_dateofcredend_353D', 'max_numberofoverdueinstlmax_1151L']
# ####### NAN count = 512590
# Use these ['mean_overdueamountmax_35A', 'max_overdueamountmaxdatemonth_284T', 'max_overdueamountmaxdateyear_994T', 'mean_pmts_overdue_1152A']
# ####### NAN count = 513987
# Use these ['max_residualamount_488A']
# ####### NAN count = 1039597
# Use these ['mean_residualamount_856A']
# ####### NAN count = 606900
# Use these ['max_totalamount_6A', 'mean_totalamount_6A']
# ####### NAN count = 545855
# Use these ['mean_totalamount_996A']
# ####### NAN count = 636448
# Use these ['mean_totaldebtoverduevalue_718A', 'mean_totaloutstanddebtvalue_668A', 'max_numberofcontrsvalue_358L']
# ####### NAN count = 297072
# Use these ['max_dateofrealrepmt_138D', 'mean_dateofrealrepmt_138D']
# ####### NAN count = 512961
# Use these ['max_lastupdate_388D', 'mean_lastupdate_388D']
# ####### NAN count = 512591
# Use these ['max_numberofoverdueinstlmaxdat_148D']
# ####### NAN count = 802351
# Use these ['mean_numberofoverdueinstlmaxdat_641D']
# ####### NAN count = 1012361
# Use these ['mean_overdueamountmax2date_1002D']
# ####### NAN count = 806653
# Use these ['max_overdueamountmax2date_1142D']
# ####### NAN count = 1007594
# ####### NAN count = 553734
# ####### NAN count = 822517
# ####### NAN count = 745109
# ####### NAN count = 545898
# ####### NAN count = 636545
# ####### NAN count = 545895
# ####### NAN count = 636544
# ####### NAN count = 512657
# ####### NAN count = 561307
# ####### NAN count = 649082
# Use these ['last_num_group1_6']
# ####### NAN count = 140386
# Use these ['last_mainoccupationinc_384A', 'last_birth_259D']
# ####### NAN count = 750301
# Use these ['max_empl_employedfrom_271D']
# ####### NAN count = 959958
# Use these ['last_personindex_1023L']
# ####### NAN count = 587206
# ####### NAN count = 772
# ####### NAN count = 262659
# ####### NAN count = 512884
# Use these ['max_pmts_month_706T', 'max_pmts_year_507T']
# ####### NAN count = 512598
# Use these ['last_pmts_month_158T', 'last_pmts_year_1139T']
# ####### NAN count = 994041
# Use these ['last_pmts_month_706T', 'last_pmts_year_507T']
# ####### NAN count = 634357
# Use these ['max_num_group1_13', 'max_num_group2_13', 'last_num_group2_13']
# ####### NAN count = 141371
# Use these ['max_num_group1_15', 'max_num_group2_15']
# ####### NAN count = 91554
# 276
# 389
# CPU times: user 1min 50s, sys: 25.5 s, total: 2min 15s
# Wall time: 1min 44s

# %%
device='gpu'
#n_samples=200000
n_est=3000
# Out:
# gpu

# %%
data_store = {
    "df_base": read_file(TEST_DIR / "test_base.parquet"),
    "depth_0": [
        read_file(TEST_DIR / "test_static_cb_0.parquet"),
        read_files(TEST_DIR / "test_static_0_*.parquet"),
    ],
    "depth_1": [
        read_files(TEST_DIR / "test_applprev_1_*.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_a_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_b_1.parquet", 1),
        read_file(TEST_DIR / "test_tax_registry_c_1.parquet", 1),
        read_files(TEST_DIR / "test_credit_bureau_a_1_*.parquet", 1),
        read_file(TEST_DIR / "test_credit_bureau_b_1.parquet", 1),
        read_file(TEST_DIR / "test_other_1.parquet", 1),
        read_file(TEST_DIR / "test_person_1.parquet", 1),
        read_file(TEST_DIR / "test_deposit_1.parquet", 1),
        read_file(TEST_DIR / "test_debitcard_1.parquet", 1),
    ],
    "depth_2": [
        read_file(TEST_DIR / "test_credit_bureau_b_2.parquet", 2),
        read_files(TEST_DIR / "test_credit_bureau_a_2_*.parquet", 2),
        read_file(TEST_DIR / "test_applprev_2.parquet", 2),
        read_file(TEST_DIR / "test_person_2.parquet", 2)
    ]
}

# %%
df_test = feature_eng(**data_store)
print("test data shape:\t", df_test.shape)
del data_store
gc.collect()
df_test = df_test.select([col for col in df_train.columns if col != "target"])
print("train data shape:\t", df_train.shape)
print("test data shape:\t", df_test.shape)

df_test, cat_cols = to_pandas(df_test, cat_cols)
df_test = reduce_mem_usage(df_test)

gc.collect()
# Out:
# test data shape:	 (10, 860)
# train data shape:	 (1526659, 389)
# test data shape:	 (10, 388)
# Memory usage of dataframe is 0.04 MB
# Memory usage after optimization is: 0.02 MB
# Decreased by 40.3%
# 0

# %%
"""def add_custom_feature(df, feature_prefixes, new_feature_name):
    used_features = []
    custom_feature = pd.Series(0, index=df.index)

    # 遍历特征列表
    for column in df.columns:
        if any(column.startswith(prefix) for prefix in feature_prefixes):
            # 将特征添加到使用的特征列表
            used_features.append(column)
            # 相加特征并更新custom_feature
            print(column)
            custom_feature += df[column]

    # 将新的自定义特征添加到数据集中
    df[new_feature_name] = custom_feature

    # 删除原始的特征
    #df = df.drop(columns=used_features)

    return df
"""

# %%
# 使用示例
#df_train = add_custom_feature(df_train, ["applicationscnt", "applicationcnt"], "totalapplicationscnt")
#df_test = add_custom_feature(df_test, ["applicationscnt", "applicationcnt"], "totalapplicationscnt")

# %%
#df_train = add_custom_feature(df_train, ["clientscnt"], "totalclientscnt")
#df_test = add_custom_feature(df_test, ["clientscnt"], "totalclientscnt")

# %%
drop_list = ['mean_credlmt_230A', 'mean_credamount_590A', 'max_financialinstitution_382M', 'max_classificationofcontr_13M', 'last_postype_4733339M', 'max_totalamount_6A', 'max_collater_valueofguarantee_1124L', 'opencred_647L', 'max_education_1138M', 'max_isbidproduct_390L', 'max_status_219L', 'last_cancelreason_3545846M', 'max_collater_valueofguarantee_876L', 'mean_overdueamount_659A', 'max_mainoccupationinc_437A', 'lastrejectcommoditycat_161M', 'max_description_351M', 'max_inittransactioncode_279L', 'max_debtoverdue_47A', 'max_credacc_credlmt_575A', 'max_subjectrole_182M', 'max_rejectreasonclient_4145042M', 'weekday_decision', 'disbursementtype_67L', 'totalsettled_863A', 'max_collaterals_typeofguarante_359M', 'last_inittransactioncode_279L', 'last_classificationofcontr_13M', 'last_rejectreasonclient_4145042M', 'max_purposeofcred_874M', 'max_num_group1_9', 'mean_credacc_credlmt_575A', 'last_isbidproduct_390L', 'max_financialinstitution_591M', 'max_subjectroles_name_838M', 'last_credacc_credlmt_575A', 'last_empls_economicalst_849M', 'max_classificationofcontr_400M', 'max_collaterals_typeofguarante_669M', 'max_collater_typofvalofguarant_298M', 'maxannuity_159A', 'max_subjectroles_name_541M', 'lastapprcredamount_781A', 'max_remitter_829L', 'last_downpmt_134A', 'mean_downpmt_134A', 'lastst_736L', 'max_cancelreason_3545846M', 'last_status_219L', 'avgoutstandbalancel6m_4187114A', 'max_contaddr_smempladdr_334L', 'max_collater_typofvalofguarant_407M', 'last_contractst_545M', 'lastrejectreasonclient_4145040M', 'max_downpmt_134A', 'last_empls_employer_name_740M', 'avginstallast24m_3658937A', 'amtinstpaidbefduel24m_4187115A', 'max_purposeofcred_426M', 'max_currdebt_94A', 'max_contractst_964M', 'lastapprcommoditycat_1041M', 'maritalst_893M', 'maxoutstandbalancel12m_4187113A', 'education_88M', 'max_language1_981M', 'last_financialinstitution_591M', 'max_contractst_545M', 'last_contaddr_matchlist_1032L', 'max_outstandingdebt_522A', 'last_language1_981M', 'maxinstallast24m_3658928A', 'max_role_1084L', 'sumoutstandtotal_3546847A', 'last_subjectrole_182M', 'last_collater_typofvalofguarant_298M', 'max_conts_role_79M', 'totaldebt_9A', 'last_sex_738L', 'mean_currdebt_94A', 'avgpmtlast12m_4525200A', 'last_subjectrole_93M', 'price_1097A', 'maininc_215A', 'last_contaddr_smempladdr_334L', 'maxlnamtstart6m_4525199A', 'last_role_1084L', 'currdebt_22A', 'annuitynextmonth_57A', 'mean_outstandingdebt_522A', 'last_collater_typofvalofguarant_407M', 'maxdebt4_972A', 'sumoutstandtotalest_4493215A', 'last_collaterals_typeofguarante_359M', 'last_purposeofcred_426M', 'max_education_927M', 'last_safeguarantyflag_411L', 'last_cacccardblochreas_147M', 'downpmt_116A', 'max_conts_type_509L', 'last_empladdr_zipcode_114M', 'last_empladdr_district_926M', 'last_education_927M', 'max_empladdr_zipcode_114M', 'paytype_783L', 'max_empladdr_district_926M', 'paytype1st_925L', 'last_purposeofcred_874M', 'last_description_351M', 'last_financialinstitution_382M', 'last_subjectroles_name_838M', 'max_cacccardblochreas_147M', 'last_classificationofcontr_400M', 'last_conts_role_79M', 'last_collaterals_typeofguarante_669M', 'last_contractst_964M', 'last_subjectroles_name_541M', 'max_numberofoutstandinstls_520L', 'max_type_25L', 'max_contaddr_matchlist_1032L', 'lastrejectcommodtypec_5251769M', 'max_safeguarantyflag_411L', 'currdebtcredtyperange_828A', 'last_mainoccupationinc_384A', 'last_incometype_1044T', 'last_currdebt_94A', 'mean_overdueamount_31A', 'mean_outstandingamount_354A', 'last_outstandingdebt_522A', 'mean_totaldebtoverduevalue_718A', 'mean_totaloutstanddebtvalue_668A', 'last_type_25L']

# %%
#df_train = df_train.drop(columns=drop_list )
#df_test = df_test.drop(columns=drop_list )

# %%
#cat_cols = df_train.select_dtypes(include=['object','category']).columns.tolist()
#cat_cols

# %% [markdown]
# ### Feature Selection

# %%
y = df_train["target"]
weeks = df_train["WEEK_NUM"]
df_train= df_train.drop(columns=["target", "case_id", "WEEK_NUM"])
cv = StratifiedGroupKFold(n_splits=5, shuffle=False)

# %%
df_train[cat_cols] = df_train[cat_cols].astype(str)
df_test[cat_cols] = df_test[cat_cols].astype(str)

# %%
class FocalLoss:

    def __init__(self, gamma, alpha=None):
        # 使用FocalLoss只需要设定以上两个参数,如果alpha=None,默认取值为1
        self.alpha = alpha
        self.gamma = gamma

    def at(self, y):
        # alpha 参数, 根据FL的定义函数,正样本权重为self.alpha,负样本权重为1 - self.alpha
        if self.alpha is None:
            return np.ones_like(y)
        return np.where(y, self.alpha, 1 - self.alpha)

    def pt(self, y, p):
        # pt和p的关系
        p = np.clip(p, 1e-15, 1 - 1e-15)
        return np.where(y, p, 1 - p)

    def __call__(self, y_true, y_pred):
        # 即FL的计算公式
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        return -at * (1 - pt) ** self.gamma * np.log(pt)

    def grad(self, y_true, y_pred):
        # 一阶导数
        y = 2 * y_true - 1  # {0, 1} -> {-1, 1}
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        g = self.gamma
        return at * y * (1 - pt) ** g * (g * pt * np.log(pt) + pt - 1)

    def hess(self, y_true, y_pred):
        # 二阶导数
        y = 2 * y_true - 1  # {0, 1} -> {-1, 1}
        at = self.at(y_true)
        pt = self.pt(y_true, y_pred)
        g = self.gamma

        u = at * y * (1 - pt) ** g
        du = -at * y * g * (1 - pt) ** (g - 1)
        v = g * pt * np.log(pt) + pt - 1
        dv = g * np.log(pt) + g + 1

        return (du * v + u * dv) * y * (pt * (1 - pt))

    def init_score(self, y_true):
        # 样本初始值寻找过程
        res = optimize.minimize_scalar(
            lambda p: self(y_true, p).sum(),
            bounds=(0, 1),
            method='bounded'
        )
        p = res.x
        log_odds = np.log(p / (1 - p))
        return log_odds

    def lgb_obj(self, preds, train_data):
        y = train_data.get_label()
        p = special.expit(preds)
        return self.grad(y, p), self.hess(y, p)

    def lgb_eval(self, preds, train_data):
        y = train_data.get_label()
        p = special.expit(preds)
        is_higher_better = False
        return 'focal_loss', self(y, p).mean(), is_higher_better
    
    def lgb_obj_sklearn(self, labels,preds):
        p = special.expit(preds)
        return self.grad(labels, p), self.hess(labels, p)
    
    def lgb_eval_sklearn(self, labels,preds):
        p = special.expit(preds)
        is_higher_better = False
        return 'focal_loss', self(labels, p).mean(), is_higher_better

# %%
params = {
    "boosting_type": "gbdt",
    #"objective": fl.lgb_obj_sklearn,
    "metric": "auc",
    "max_depth": 10,  
    "learning_rate": 0.05,
    "n_estimators": 2000,  
    "colsample_bytree": 0.8,
    "colsample_bynode": 0.8,
    "verbose": -1,
    "random_state": 42,
    "reg_alpha": 0.1,
    "reg_lambda": 10,
    "extra_trees":True,
    'num_leaves':64,
    "device": device, 
    "verbose": -1,
}

# %%
# %%time
from scipy import optimize
from scipy import special
from catboost import CatBoostClassifier, Pool

fitted_models_cat = []
fitted_models_lgb = []

cv_scores_cat = []
cv_scores_lgb = []

for idx_train, idx_valid in cv.split(df_train, y, groups=weeks):#
    X_train, y_train = df_train.iloc[idx_train], y.iloc[idx_train]# 
    X_valid, y_valid = df_train.iloc[idx_valid], y.iloc[idx_valid]
    train_pool = Pool(X_train, y_train,cat_features=cat_cols)
    val_pool = Pool(X_valid, y_valid,cat_features=cat_cols)
    clf = CatBoostClassifier(
    eval_metric='AUC',
    task_type='GPU',
    learning_rate=0.06,
    iterations=n_est)
    random_seed=3107
    clf.fit(train_pool, eval_set=val_pool,verbose=300)
    fitted_models_cat.append(clf)
    y_pred_valid = clf.predict_proba(X_valid)[:,1]
    print("#######################")
    print(clf.predict_proba(X_valid))
    auc_score = roc_auc_score(y_valid, y_pred_valid)
    cv_scores_cat.append(auc_score)
    
    X_train[cat_cols] = X_train[cat_cols].astype("category")
    X_valid[cat_cols] = X_valid[cat_cols].astype("category")
    
    fl = FocalLoss(alpha=0.25, gamma=5)
    initScore_fit = np.full_like(y_train, fl.init_score(y_train), dtype=float)
    initScore_val = np.full_like(y_valid, fl.init_score(y_valid), dtype=float)

    model = lgb.LGBMClassifier(objective=fl.lgb_obj_sklearn,**params)
    model.fit(
        X_train, y_train,
        eval_set = [(X_train, y_train),(X_valid, y_valid)],
        init_score= initScore_fit,
        eval_init_score =[initScore_fit,initScore_val],
        eval_metric=fl.lgb_eval_sklearn,
        callbacks = [lgb.log_evaluation(20), lgb.early_stopping(100)] )

    fitted_models_lgb.append(model)
    print("#######################")
    y_pred_valid = special.expit(model.predict_proba(X_valid))
    

    print(y_pred_valid)
    auc_score = roc_auc_score(y_valid, y_pred_valid)
    cv_scores_lgb.append(auc_score)
    
    
print("CV AUC scores: ", cv_scores_cat)
print("Maximum CV AUC score: ", np.mean(cv_scores_cat))


print("CV AUC scores: ", cv_scores_lgb)
print("Maximum CV AUC score: ", np.mean(cv_scores_lgb))
# Out:
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# 1 warning generated.
# [LightGBM] [Info] Using self-defined objective function
# Training until validation scores don't improve for 100 rounds
# [20]	training's auc: 0.813464	training's focal_loss: 0.00192362	valid_1's auc: 0.803724	valid_1's focal_loss: 0.00203814
# [40]	training's auc: 0.828974	training's focal_loss: 0.00181957	valid_1's auc: 0.817993	valid_1's focal_loss: 0.00193857
# [60]	training's auc: 0.840187	training's focal_loss: 0.00175937	valid_1's auc: 0.827781	valid_1's focal_loss: 0.001884
# [80]	training's auc: 0.84704	training's focal_loss: 0.00172164	valid_1's auc: 0.833418	valid_1's focal_loss: 0.00185201
# [100]	training's auc: 0.85211	training's focal_loss: 0.00169547	valid_1's auc: 0.837166	valid_1's focal_loss: 0.00183183
# [120]	training's auc: 0.855998	training's focal_loss: 0.00167617	valid_1's auc: 0.839756	valid_1's focal_loss: 0.00181832
# [140]	training's auc: 0.859317	training's focal_loss: 0.00166047	valid_1's auc: 0.841642	valid_1's focal_loss: 0.0018087
# [160]	training's auc: 0.862229	training's focal_loss: 0.00164743	valid_1's auc: 0.843178	valid_1's focal_loss: 0.00180144
# [180]	training's auc: 0.864774	training's focal_loss: 0.00163593	valid_1's auc: 0.844415	valid_1's focal_loss: 0.00179547
# [200]	training's auc: 0.866996	training's focal_loss: 0.00162597	valid_1's auc: 0.845501	valid_1's focal_loss: 0.00179052
# [220]	training's auc: 0.869075	training's focal_loss: 0.00161685	valid_1's auc: 0.84634	valid_1's focal_loss: 0.00178657
# [240]	training's auc: 0.871055	training's focal_loss: 0.00160822	valid_1's auc: 0.847107	valid_1's focal_loss: 0.00178303
# [260]	training's auc: 0.872974	training's focal_loss: 0.00160012	valid_1's auc: 0.847803	valid_1's focal_loss: 0.00178012
# [280]	training's auc: 0.874702	training's focal_loss: 0.00159271	valid_1's auc: 0.848377	valid_1's focal_loss: 0.00177766
# [300]	training's auc: 0.876371	training's focal_loss: 0.00158558	valid_1's auc: 0.848835	valid_1's focal_loss: 0.00177556
# [320]	training's auc: 0.878017	training's focal_loss: 0.00157857	valid_1's auc: 0.849331	valid_1's focal_loss: 0.00177335
# [340]	training's auc: 0.879552	training's focal_loss: 0.00157211	valid_1's auc: 0.849777	valid_1's focal_loss: 0.00177142
# [360]	training's auc: 0.881047	training's focal_loss: 0.0015657	valid_1's auc: 0.850139	valid_1's focal_loss: 0.00176989
# [380]	training's auc: 0.882528	training's focal_loss: 0.00155943	valid_1's auc: 0.850522	valid_1's focal_loss: 0.00176826
# [400]	training's auc: 0.883882	training's focal_loss: 0.00155354	valid_1's auc: 0.850787	valid_1's focal_loss: 0.00176712
# [420]	training's auc: 0.885217	training's focal_loss: 0.00154781	valid_1's auc: 0.851009	valid_1's focal_loss: 0.00176617
# [440]	training's auc: 0.886458	training's focal_loss: 0.00154241	valid_1's auc: 0.851214	valid_1's focal_loss: 0.00176529
# [460]	training's auc: 0.887675	training's focal_loss: 0.00153718	valid_1's auc: 0.851419	valid_1's focal_loss: 0.0017644
# [480]	training's auc: 0.888846	training's focal_loss: 0.00153202	valid_1's auc: 0.851594	valid_1's focal_loss: 0.00176362
# [500]	training's auc: 0.89002	training's focal_loss: 0.00152686	valid_1's auc: 0.851776	valid_1's focal_loss: 0.00176284
# [520]	training's auc: 0.891182	training's focal_loss: 0.00152188	valid_1's auc: 0.851998	valid_1's focal_loss: 0.00176204
# [540]	training's auc: 0.892266	training's focal_loss: 0.00151707	valid_1's auc: 0.852084	valid_1's focal_loss: 0.00176163
# [560]	training's auc: 0.89342	training's focal_loss: 0.00151197	valid_1's auc: 0.852216	valid_1's focal_loss: 0.00176105
# [580]	training's auc: 0.89449	training's focal_loss: 0.00150734	valid_1's auc: 0.852336	valid_1's focal_loss: 0.00176056
# [600]	training's auc: 0.895547	training's focal_loss: 0.00150271	valid_1's auc: 0.852443	valid_1's focal_loss: 0.0017601
# [620]	training's auc: 0.896595	training's focal_loss: 0.00149805	valid_1's auc: 0.852534	valid_1's focal_loss: 0.00175968
# [640]	training's auc: 0.897606	training's focal_loss: 0.00149345	valid_1's auc: 0.852616	valid_1's focal_loss: 0.00175933
# [660]	training's auc: 0.898633	training's focal_loss: 0.00148882	valid_1's auc: 0.852698	valid_1's focal_loss: 0.00175901
# [680]	training's auc: 0.899652	training's focal_loss: 0.00148433	valid_1's auc: 0.852753	valid_1's focal_loss: 0.00175881
# [700]	training's auc: 0.90069	training's focal_loss: 0.00147966	valid_1's auc: 0.852861	valid_1's focal_loss: 0.0017584
# [720]	training's auc: 0.901614	training's focal_loss: 0.00147545	valid_1's auc: 0.852916	valid_1's focal_loss: 0.00175828
# [740]	training's auc: 0.902596	training's focal_loss: 0.00147102	valid_1's auc: 0.853008	valid_1's focal_loss: 0.00175792
# [760]	training's auc: 0.903522	training's focal_loss: 0.00146689	valid_1's auc: 0.853123	valid_1's focal_loss: 0.00175756
# [780]	training's auc: 0.904402	training's focal_loss: 0.00146282	valid_1's auc: 0.853156	valid_1's focal_loss: 0.00175745
# [800]	training's auc: 0.90529	training's focal_loss: 0.00145864	valid_1's auc: 0.853277	valid_1's focal_loss: 0.00175705
# [820]	training's auc: 0.906135	training's focal_loss: 0.00145473	valid_1's auc: 0.853325	valid_1's focal_loss: 0.00175691
# [840]	training's auc: 0.906995	training's focal_loss: 0.00145067	valid_1's auc: 0.853383	valid_1's focal_loss: 0.00175674
# [860]	training's auc: 0.907879	training's focal_loss: 0.00144659	valid_1's auc: 0.853464	valid_1's focal_loss: 0.00175646
# [880]	training's auc: 0.908735	training's focal_loss: 0.00144267	valid_1's auc: 0.853511	valid_1's focal_loss: 0.00175632
# [900]	training's auc: 0.909544	training's focal_loss: 0.00143884	valid_1's auc: 0.853506	valid_1's focal_loss: 0.00175635
# [920]	training's auc: 0.910393	training's focal_loss: 0.0014349	valid_1's auc: 0.853567	valid_1's focal_loss: 0.00175618
# [940]	training's auc: 0.911172	training's focal_loss: 0.00143121	valid_1's auc: 0.853622	valid_1's focal_loss: 0.00175597
# [960]	training's auc: 0.911928	training's focal_loss: 0.0014276	valid_1's auc: 0.853632	valid_1's focal_loss: 0.00175598
# [980]	training's auc: 0.912645	training's focal_loss: 0.00142404	valid_1's auc: 0.853678	valid_1's focal_loss: 0.00175587
# [1000]	training's auc: 0.91341	training's focal_loss: 0.00142038	valid_1's auc: 0.853698	valid_1's focal_loss: 0.00175581
# [1020]	training's auc: 0.914088	training's focal_loss: 0.00141698	valid_1's auc: 0.853711	valid_1's focal_loss: 0.00175576
# [1040]	training's auc: 0.91485	training's focal_loss: 0.00141337	valid_1's auc: 0.8537	valid_1's focal_loss: 0.00175587
# [1060]	training's auc: 0.915556	training's focal_loss: 0.00140994	valid_1's auc: 0.853747	valid_1's focal_loss: 0.00175573
# [1080]	training's auc: 0.916291	training's focal_loss: 0.00140639	valid_1's auc: 0.853755	valid_1's focal_loss: 0.00175579
# [1100]	training's auc: 0.917031	training's focal_loss: 0.00140283	valid_1's auc: 0.853813	valid_1's focal_loss: 0.00175564
# [1120]	training's auc: 0.917719	training's focal_loss: 0.00139933	valid_1's auc: 0.853722	valid_1's focal_loss: 0.00175606
# [1140]	training's auc: 0.918416	training's focal_loss: 0.00139587	valid_1's auc: 0.853728	valid_1's focal_loss: 0.00175617
# [1160]	training's auc: 0.919142	training's focal_loss: 0.00139235	valid_1's auc: 0.85375	valid_1's focal_loss: 0.00175611
# [1180]	training's auc: 0.919821	training's focal_loss: 0.00138908	valid_1's auc: 0.85376	valid_1's focal_loss: 0.00175614
# Early stopping, best iteration is:
# [1099]	training's auc: 0.916992	training's focal_loss: 0.00140301	valid_1's auc: 0.853816	valid_1's focal_loss: 0.00175561
# #######################
# [0.45597122 0.46935659 0.52266633 ... 0.42478415 0.53631887 0.43273553]
# [LightGBM] [Info] Using self-defined objective function
# Training until validation scores don't improve for 100 rounds
# [20]	training's auc: 0.812908	training's focal_loss: 0.00195704	valid_1's auc: 0.806784	valid_1's focal_loss: 0.00190856
# [40]	training's auc: 0.829045	training's focal_loss: 0.00184953	valid_1's auc: 0.821073	valid_1's focal_loss: 0.00181199
# [60]	training's auc: 0.839213	training's focal_loss: 0.00179094	valid_1's auc: 0.829849	valid_1's focal_loss: 0.00176144
# [80]	training's auc: 0.846017	training's focal_loss: 0.00175361	valid_1's auc: 0.835312	valid_1's focal_loss: 0.00173108
# [100]	training's auc: 0.85114	training's focal_loss: 0.00172671	valid_1's auc: 0.839214	valid_1's focal_loss: 0.00171025
# [120]	training's auc: 0.855078	training's focal_loss: 0.00170702	valid_1's auc: 0.841849	valid_1's focal_loss: 0.00169667
# [140]	training's auc: 0.858331	training's focal_loss: 0.00169158	valid_1's auc: 0.843921	valid_1's focal_loss: 0.00168675
# [160]	training's auc: 0.861163	training's focal_loss: 0.00167849	valid_1's auc: 0.845574	valid_1's focal_loss: 0.00167903
# [180]	training's auc: 0.863702	training's focal_loss: 0.00166709	valid_1's auc: 0.846695	valid_1's focal_loss: 0.00167367
# [200]	training's auc: 0.86602	training's focal_loss: 0.00165678	valid_1's auc: 0.847686	valid_1's focal_loss: 0.00166926
# [220]	training's auc: 0.868196	training's focal_loss: 0.00164721	valid_1's auc: 0.848599	valid_1's focal_loss: 0.0016653
# [240]	training's auc: 0.870173	training's focal_loss: 0.00163868	valid_1's auc: 0.849226	valid_1's focal_loss: 0.00166247
# [260]	training's auc: 0.87195	training's focal_loss: 0.00163101	valid_1's auc: 0.849743	valid_1's focal_loss: 0.00166016
# [280]	training's auc: 0.873682	training's focal_loss: 0.00162347	valid_1's auc: 0.850299	valid_1's focal_loss: 0.00165789
# [300]	training's auc: 0.875292	training's focal_loss: 0.00161643	valid_1's auc: 0.850745	valid_1's focal_loss: 0.00165607
# [320]	training's auc: 0.876862	training's focal_loss: 0.00160965	valid_1's auc: 0.851135	valid_1's focal_loss: 0.00165446
# [340]	training's auc: 0.8784	training's focal_loss: 0.0016031	valid_1's auc: 0.851522	valid_1's focal_loss: 0.00165289
# [360]	training's auc: 0.879857	training's focal_loss: 0.00159689	valid_1's auc: 0.851895	valid_1's focal_loss: 0.00165146
# [380]	training's auc: 0.881272	training's focal_loss: 0.00159076	valid_1's auc: 0.852142	valid_1's focal_loss: 0.00165044
# [400]	training's auc: 0.882582	training's focal_loss: 0.00158506	valid_1's auc: 0.852395	valid_1's focal_loss: 0.00164945
# [420]	training's auc: 0.883846	training's focal_loss: 0.00157939	valid_1's auc: 0.852634	valid_1's focal_loss: 0.00164855
# [440]	training's auc: 0.885056	training's focal_loss: 0.00157408	valid_1's auc: 0.852823	valid_1's focal_loss: 0.00164785
# [460]	training's auc: 0.886309	training's focal_loss: 0.00156859	valid_1's auc: 0.852991	valid_1's focal_loss: 0.0016472
# [480]	training's auc: 0.887532	training's focal_loss: 0.0015632	valid_1's auc: 0.853223	valid_1's focal_loss: 0.00164631
# [500]	training's auc: 0.888657	training's focal_loss: 0.0015582	valid_1's auc: 0.853376	valid_1's focal_loss: 0.00164576
# [520]	training's auc: 0.889815	training's focal_loss: 0.00155301	valid_1's auc: 0.853568	valid_1's focal_loss: 0.00164508
# [540]	training's auc: 0.89098	training's focal_loss: 0.00154786	valid_1's auc: 0.853699	valid_1's focal_loss: 0.00164461
# [560]	training's auc: 0.892004	training's focal_loss: 0.00154327	valid_1's auc: 0.853835	valid_1's focal_loss: 0.0016441
# [580]	training's auc: 0.89313	training's focal_loss: 0.0015383	valid_1's auc: 0.853944	valid_1's focal_loss: 0.0016437
# [600]	training's auc: 0.894126	training's focal_loss: 0.00153373	valid_1's auc: 0.854066	valid_1's focal_loss: 0.00164331
# [620]	training's auc: 0.895172	training's focal_loss: 0.00152898	valid_1's auc: 0.854249	valid_1's focal_loss: 0.00164279
# [640]	training's auc: 0.896193	training's focal_loss: 0.00152455	valid_1's auc: 0.854324	valid_1's focal_loss: 0.00164258
# [660]	training's auc: 0.897271	training's focal_loss: 0.00151965	valid_1's auc: 0.85445	valid_1's focal_loss: 0.00164221
# [680]	training's auc: 0.898255	training's focal_loss: 0.00151529	valid_1's auc: 0.854549	valid_1's focal_loss: 0.00164194
# [700]	training's auc: 0.899239	training's focal_loss: 0.00151074	valid_1's auc: 0.854609	valid_1's focal_loss: 0.00164178
# [720]	training's auc: 0.900171	training's focal_loss: 0.0015066	valid_1's auc: 0.854586	valid_1's focal_loss: 0.00164192
# [740]	training's auc: 0.901053	training's focal_loss: 0.00150247	valid_1's auc: 0.85468	valid_1's focal_loss: 0.00164171
# [760]	training's auc: 0.901971	training's focal_loss: 0.00149813	valid_1's auc: 0.854759	valid_1's focal_loss: 0.00164147
# [780]	training's auc: 0.902943	training's focal_loss: 0.00149368	valid_1's auc: 0.854853	valid_1's focal_loss: 0.00164127
# [800]	training's auc: 0.903832	training's focal_loss: 0.00148954	valid_1's auc: 0.854886	valid_1's focal_loss: 0.00164122
# [820]	training's auc: 0.904713	training's focal_loss: 0.00148549	valid_1's auc: 0.854935	valid_1's focal_loss: 0.00164115
# [840]	training's auc: 0.90557	training's focal_loss: 0.00148144	valid_1's auc: 0.854974	valid_1's focal_loss: 0.0016411
# [860]	training's auc: 0.906446	training's focal_loss: 0.0014773	valid_1's auc: 0.854966	valid_1's focal_loss: 0.00164124
# [880]	training's auc: 0.907282	training's focal_loss: 0.00147333	valid_1's auc: 0.855006	valid_1's focal_loss: 0.00164118
# [900]	training's auc: 0.908109	training's focal_loss: 0.00146939	valid_1's auc: 0.855003	valid_1's focal_loss: 0.00164135
# [920]	training's auc: 0.908916	training's focal_loss: 0.0014655	valid_1's auc: 0.854997	valid_1's focal_loss: 0.00164153
# Early stopping, best iteration is:
# [833]	training's auc: 0.90528	training's focal_loss: 0.00148284	valid_1's auc: 0.85501	valid_1's focal_loss: 0.00164098
# #######################
# [0.52259375 0.55028883 0.53753809 ... 0.42731682 0.36516987 0.39998282]
# [LightGBM] [Info] Using self-defined objective function
# Training until validation scores don't improve for 100 rounds
# [20]	training's auc: 0.81161	training's focal_loss: 0.00195271	valid_1's auc: 0.808909	valid_1's focal_loss: 0.00192398
# [40]	training's auc: 0.827317	training's focal_loss: 0.00184788	valid_1's auc: 0.823659	valid_1's focal_loss: 0.00182394
# [60]	training's auc: 0.838193	training's focal_loss: 0.0017882	valid_1's auc: 0.833313	valid_1's focal_loss: 0.00176968
# [80]	training's auc: 0.845075	training's focal_loss: 0.00175115	valid_1's auc: 0.839037	valid_1's focal_loss: 0.00173791
# [100]	training's auc: 0.850356	training's focal_loss: 0.00172434	valid_1's auc: 0.843061	valid_1's focal_loss: 0.00171669
# [120]	training's auc: 0.854393	training's focal_loss: 0.00170464	valid_1's auc: 0.845688	valid_1's focal_loss: 0.00170291
# [140]	training's auc: 0.857686	training's focal_loss: 0.00168915	valid_1's auc: 0.847688	valid_1's focal_loss: 0.00169305
# [160]	training's auc: 0.860591	training's focal_loss: 0.00167575	valid_1's auc: 0.849386	valid_1's focal_loss: 0.0016852
# [180]	training's auc: 0.863143	training's focal_loss: 0.00166452	valid_1's auc: 0.850577	valid_1's focal_loss: 0.00167983
# [200]	training's auc: 0.865461	training's focal_loss: 0.00165417	valid_1's auc: 0.851705	valid_1's focal_loss: 0.00167493
# [220]	training's auc: 0.867515	training's focal_loss: 0.00164507	valid_1's auc: 0.852517	valid_1's focal_loss: 0.00167133
# [240]	training's auc: 0.869469	training's focal_loss: 0.00163667	valid_1's auc: 0.853171	valid_1's focal_loss: 0.00166852
# [260]	training's auc: 0.871365	training's focal_loss: 0.00162859	valid_1's auc: 0.853877	valid_1's focal_loss: 0.00166582
# [280]	training's auc: 0.873096	training's focal_loss: 0.00162109	valid_1's auc: 0.854488	valid_1's focal_loss: 0.00166325
# [300]	training's auc: 0.874728	training's focal_loss: 0.00161411	valid_1's auc: 0.854937	valid_1's focal_loss: 0.00166144
# [320]	training's auc: 0.87629	training's focal_loss: 0.00160753	valid_1's auc: 0.855354	valid_1's focal_loss: 0.00165983
# [340]	training's auc: 0.877826	training's focal_loss: 0.00160084	valid_1's auc: 0.855687	valid_1's focal_loss: 0.00165851
# [360]	training's auc: 0.879352	training's focal_loss: 0.00159446	valid_1's auc: 0.856015	valid_1's focal_loss: 0.00165726
# [380]	training's auc: 0.880771	training's focal_loss: 0.00158829	valid_1's auc: 0.856431	valid_1's focal_loss: 0.00165561
# [400]	training's auc: 0.882129	training's focal_loss: 0.00158238	valid_1's auc: 0.856748	valid_1's focal_loss: 0.00165442
# [420]	training's auc: 0.883486	training's focal_loss: 0.00157652	valid_1's auc: 0.857071	valid_1's focal_loss: 0.00165323
# [440]	training's auc: 0.884789	training's focal_loss: 0.00157088	valid_1's auc: 0.857266	valid_1's focal_loss: 0.00165252
# [460]	training's auc: 0.886026	training's focal_loss: 0.00156548	valid_1's auc: 0.857404	valid_1's focal_loss: 0.00165206
# [480]	training's auc: 0.887333	training's focal_loss: 0.00155993	valid_1's auc: 0.857568	valid_1's focal_loss: 0.00165147
# [500]	training's auc: 0.888495	training's focal_loss: 0.00155476	valid_1's auc: 0.857767	valid_1's focal_loss: 0.00165089
# [520]	training's auc: 0.889607	training's focal_loss: 0.00154983	valid_1's auc: 0.857896	valid_1's focal_loss: 0.00165044
# [540]	training's auc: 0.890786	training's focal_loss: 0.00154466	valid_1's auc: 0.85805	valid_1's focal_loss: 0.00164994
# [560]	training's auc: 0.891909	training's focal_loss: 0.00153972	valid_1's auc: 0.858242	valid_1's focal_loss: 0.0016493
# [580]	training's auc: 0.893033	training's focal_loss: 0.00153485	valid_1's auc: 0.858393	valid_1's focal_loss: 0.00164887
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's auc: 0.894055	training's focal_loss: 0.00153018	valid_1's auc: 0.858541	valid_1's focal_loss: 0.00164841
# [620]	training's auc: 0.895079	training's focal_loss: 0.00152566	valid_1's auc: 0.858641	valid_1's focal_loss: 0.00164813
# [640]	training's auc: 0.896053	training's focal_loss: 0.0015212	valid_1's auc: 0.858743	valid_1's focal_loss: 0.00164784
# [660]	training's auc: 0.89705	training's focal_loss: 0.00151676	valid_1's auc: 0.858805	valid_1's focal_loss: 0.00164772
# [680]	training's auc: 0.897975	training's focal_loss: 0.00151243	valid_1's auc: 0.858845	valid_1's focal_loss: 0.00164769
# [700]	training's auc: 0.898976	training's focal_loss: 0.00150801	valid_1's auc: 0.858931	valid_1's focal_loss: 0.00164754
# [720]	training's auc: 0.899919	training's focal_loss: 0.00150373	valid_1's auc: 0.859	valid_1's focal_loss: 0.00164743
# [740]	training's auc: 0.900807	training's focal_loss: 0.00149964	valid_1's auc: 0.859043	valid_1's focal_loss: 0.0016474
# [760]	training's auc: 0.901674	training's focal_loss: 0.00149573	valid_1's auc: 0.8591	valid_1's focal_loss: 0.00164728
# [780]	training's auc: 0.902562	training's focal_loss: 0.0014917	valid_1's auc: 0.859172	valid_1's focal_loss: 0.00164714
# [800]	training's auc: 0.903415	training's focal_loss: 0.00148767	valid_1's auc: 0.859184	valid_1's focal_loss: 0.0016472
# [820]	training's auc: 0.904315	training's focal_loss: 0.0014836	valid_1's auc: 0.859147	valid_1's focal_loss: 0.00164748
# [840]	training's auc: 0.905112	training's focal_loss: 0.00147984	valid_1's auc: 0.859188	valid_1's focal_loss: 0.00164748
# [860]	training's auc: 0.905963	training's focal_loss: 0.00147588	valid_1's auc: 0.859202	valid_1's focal_loss: 0.00164753
# [880]	training's auc: 0.906794	training's focal_loss: 0.00147203	valid_1's auc: 0.859256	valid_1's focal_loss: 0.00164744
# Early stopping, best iteration is:
# [793]	training's auc: 0.90311	training's focal_loss: 0.00148906	valid_1's auc: 0.859197	valid_1's focal_loss: 0.0016471
# #######################
# [0.50518417 0.51033344 0.48431829 ... 0.52531516 0.38551359 0.38801622]
# [180]	training's auc: 0.86322	training's focal_loss: 0.00165786	valid_1's auc: 0.850299	valid_1's focal_loss: 0.00170744
# [200]	training's auc: 0.865592	training's focal_loss: 0.00164757	valid_1's auc: 0.85135	valid_1's focal_loss: 0.00170251
# [220]	training's auc: 0.867753	training's focal_loss: 0.00163823	valid_1's auc: 0.852089	valid_1's focal_loss: 0.00169891
# [240]	training's auc: 0.86978	training's focal_loss: 0.00162958	valid_1's auc: 0.852724	valid_1's focal_loss: 0.00169588
# [260]	training's auc: 0.871647	training's focal_loss: 0.00162162	valid_1's auc: 0.85337	valid_1's focal_loss: 0.00169303
# [280]	training's auc: 0.87339	training's focal_loss: 0.00161418	valid_1's auc: 0.853916	valid_1's focal_loss: 0.00169068
# [300]	training's auc: 0.875045	training's focal_loss: 0.00160711	valid_1's auc: 0.854366	valid_1's focal_loss: 0.00168867
# [320]	training's auc: 0.876587	training's focal_loss: 0.0016005	valid_1's auc: 0.854783	valid_1's focal_loss: 0.00168689
# [340]	training's auc: 0.878133	training's focal_loss: 0.00159395	valid_1's auc: 0.855178	valid_1's focal_loss: 0.0016853
# [360]	training's auc: 0.879639	training's focal_loss: 0.00158757	valid_1's auc: 0.855524	valid_1's focal_loss: 0.001684
# [380]	training's auc: 0.88102	training's focal_loss: 0.00158162	valid_1's auc: 0.855842	valid_1's focal_loss: 0.00168265
# [400]	training's auc: 0.882385	training's focal_loss: 0.00157573	valid_1's auc: 0.856147	valid_1's focal_loss: 0.00168151
# [420]	training's auc: 0.883733	training's focal_loss: 0.00157	valid_1's auc: 0.85639	valid_1's focal_loss: 0.00168054
# [440]	training's auc: 0.885048	training's focal_loss: 0.00156444	valid_1's auc: 0.856573	valid_1's focal_loss: 0.00167982
# [460]	training's auc: 0.886292	training's focal_loss: 0.0015591	valid_1's auc: 0.856726	valid_1's focal_loss: 0.00167911
# [480]	training's auc: 0.887563	training's focal_loss: 0.00155358	valid_1's auc: 0.856848	valid_1's focal_loss: 0.00167857
# [500]	training's auc: 0.88872	training's focal_loss: 0.0015484	valid_1's auc: 0.85705	valid_1's focal_loss: 0.00167785
# [520]	training's auc: 0.889939	training's focal_loss: 0.00154305	valid_1's auc: 0.857288	valid_1's focal_loss: 0.00167698
# [540]	training's auc: 0.89112	training's focal_loss: 0.001538	valid_1's auc: 0.857435	valid_1's focal_loss: 0.00167643
# [560]	training's auc: 0.892254	training's focal_loss: 0.00153297	valid_1's auc: 0.857584	valid_1's focal_loss: 0.00167594
# [580]	training's auc: 0.893332	training's focal_loss: 0.00152809	valid_1's auc: 0.857685	valid_1's focal_loss: 0.00167561
# [600]	training's auc: 0.894419	training's focal_loss: 0.00152337	valid_1's auc: 0.857818	valid_1's focal_loss: 0.00167515
# [620]	training's auc: 0.895512	training's focal_loss: 0.00151846	valid_1's auc: 0.857871	valid_1's focal_loss: 0.00167497
# [640]	training's auc: 0.896548	training's focal_loss: 0.00151385	valid_1's auc: 0.857925	valid_1's focal_loss: 0.00167484
# [660]	training's auc: 0.897515	training's focal_loss: 0.00150942	valid_1's auc: 0.858018	valid_1's focal_loss: 0.00167453
# [680]	training's auc: 0.898475	training's focal_loss: 0.00150504	valid_1's auc: 0.858082	valid_1's focal_loss: 0.00167436
# [700]	training's auc: 0.899449	training's focal_loss: 0.00150069	valid_1's auc: 0.858169	valid_1's focal_loss: 0.00167416
# [720]	training's auc: 0.900372	training's focal_loss: 0.00149647	valid_1's auc: 0.85831	valid_1's focal_loss: 0.00167376
# [740]	training's auc: 0.901336	training's focal_loss: 0.00149215	valid_1's auc: 0.858372	valid_1's focal_loss: 0.00167358
# [760]	training's auc: 0.902284	training's focal_loss: 0.00148789	valid_1's auc: 0.858463	valid_1's focal_loss: 0.00167332
# [780]	training's auc: 0.903198	training's focal_loss: 0.00148374	valid_1's auc: 0.858498	valid_1's focal_loss: 0.00167326
# [800]	training's auc: 0.904103	training's focal_loss: 0.00147955	valid_1's auc: 0.858519	valid_1's focal_loss: 0.00167333
# [820]	training's auc: 0.904981	training's focal_loss: 0.00147542	valid_1's auc: 0.858603	valid_1's focal_loss: 0.00167311
# [840]	training's auc: 0.905754	training's focal_loss: 0.00147168	valid_1's auc: 0.858598	valid_1's focal_loss: 0.00167325
# [860]	training's auc: 0.906577	training's focal_loss: 0.00146775	valid_1's auc: 0.858629	valid_1's focal_loss: 0.00167327
# [880]	training's auc: 0.907412	training's focal_loss: 0.00146376	valid_1's auc: 0.85868	valid_1's focal_loss: 0.00167318
# [900]	training's auc: 0.908243	training's focal_loss: 0.00145986	valid_1's auc: 0.858713	valid_1's focal_loss: 0.00167318
# [920]	training's auc: 0.909109	training's focal_loss: 0.00145584	valid_1's auc: 0.858724	valid_1's focal_loss: 0.00167326
# [940]	training's auc: 0.90993	training's focal_loss: 0.00145202	valid_1's auc: 0.858707	valid_1's focal_loss: 0.00167339
# [960]	training's auc: 0.910716	training's focal_loss: 0.00144824	valid_1's auc: 0.858709	valid_1's focal_loss: 0.00167351
# Early stopping, best iteration is:
# [875]	training's auc: 0.907182	training's focal_loss: 0.0014648	valid_1's auc: 0.858689	valid_1's focal_loss: 0.00167311
# #######################
# [0.52902742 0.54407156 0.45647081 ... 0.4972513  0.41847867 0.43797522]
# [LightGBM] [Info] Using self-defined objective function
# Training until validation scores don't improve for 100 rounds
# [20]	training's auc: 0.812256	training's focal_loss: 0.00195052	valid_1's auc: 0.803213	valid_1's focal_loss: 0.00193997
# [40]	training's auc: 0.828047	training's focal_loss: 0.00184533	valid_1's auc: 0.81872	valid_1's focal_loss: 0.00184186
# [60]	training's auc: 0.838958	training's focal_loss: 0.00178506	valid_1's auc: 0.828954	valid_1's focal_loss: 0.00178741
# [80]	training's auc: 0.84593	training's focal_loss: 0.00174744	valid_1's auc: 0.834665	valid_1's focal_loss: 0.001756
# [100]	training's auc: 0.850887	training's focal_loss: 0.00172154	valid_1's auc: 0.838517	valid_1's focal_loss: 0.00173591
# [120]	training's auc: 0.854728	training's focal_loss: 0.0017022	valid_1's auc: 0.841094	valid_1's focal_loss: 0.00172252
# [140]	training's auc: 0.858126	training's focal_loss: 0.00168667	valid_1's auc: 0.843219	valid_1's focal_loss: 0.0017127
# [160]	training's auc: 0.861162	training's focal_loss: 0.00167296	valid_1's auc: 0.845001	valid_1's focal_loss: 0.00170461
# [180]	training's auc: 0.86365	training's focal_loss: 0.00166182	valid_1's auc: 0.846232	valid_1's focal_loss: 0.00169911
# [200]	training's auc: 0.866019	training's focal_loss: 0.00165139	valid_1's auc: 0.847344	valid_1's focal_loss: 0.00169434
# [220]	training's auc: 0.868217	training's focal_loss: 0.00164186	valid_1's auc: 0.848271	valid_1's focal_loss: 0.00169048
# [240]	training's auc: 0.870143	training's focal_loss: 0.00163341	valid_1's auc: 0.849082	valid_1's focal_loss: 0.00168717
# [260]	training's auc: 0.871949	training's focal_loss: 0.00162567	valid_1's auc: 0.849736	valid_1's focal_loss: 0.00168457
# [280]	training's auc: 0.873712	training's focal_loss: 0.00161805	valid_1's auc: 0.850314	valid_1's focal_loss: 0.00168222
# [300]	training's auc: 0.875361	training's focal_loss: 0.0016109	valid_1's auc: 0.850844	valid_1's focal_loss: 0.00168012
# [320]	training's auc: 0.876961	training's focal_loss: 0.00160406	valid_1's auc: 0.851245	valid_1's focal_loss: 0.00167866
# [340]	training's auc: 0.878467	training's focal_loss: 0.00159761	valid_1's auc: 0.851641	valid_1's focal_loss: 0.00167719
# [360]	training's auc: 0.879953	training's focal_loss: 0.00159118	valid_1's auc: 0.851976	valid_1's focal_loss: 0.00167587
# [380]	training's auc: 0.881351	training's focal_loss: 0.0015851	valid_1's auc: 0.852313	valid_1's focal_loss: 0.00167458
# [400]	training's auc: 0.882787	training's focal_loss: 0.00157904	valid_1's auc: 0.852648	valid_1's focal_loss: 0.00167333
# [420]	training's auc: 0.884134	training's focal_loss: 0.00157312	valid_1's auc: 0.852882	valid_1's focal_loss: 0.00167252
# [440]	training's auc: 0.88546	training's focal_loss: 0.00156746	valid_1's auc: 0.853123	valid_1's focal_loss: 0.00167167
# [460]	training's auc: 0.886743	training's focal_loss: 0.00156195	valid_1's auc: 0.853333	valid_1's focal_loss: 0.00167103
# [480]	training's auc: 0.887957	training's focal_loss: 0.00155651	valid_1's auc: 0.853529	valid_1's focal_loss: 0.00167037
# [500]	training's auc: 0.88917	training's focal_loss: 0.00155111	valid_1's auc: 0.853684	valid_1's focal_loss: 0.00166984
# [520]	training's auc: 0.890263	training's focal_loss: 0.00154629	valid_1's auc: 0.853813	valid_1's focal_loss: 0.00166947
# [540]	training's auc: 0.891298	training's focal_loss: 0.00154168	valid_1's auc: 0.853898	valid_1's focal_loss: 0.00166929
# [560]	training's auc: 0.892416	training's focal_loss: 0.00153675	valid_1's auc: 0.854013	valid_1's focal_loss: 0.00166896
# [580]	training's auc: 0.893526	training's focal_loss: 0.0015317	valid_1's auc: 0.854151	valid_1's focal_loss: 0.00166859
# [600]	training's auc: 0.894574	training's focal_loss: 0.00152695	valid_1's auc: 0.854217	valid_1's focal_loss: 0.00166856
# [620]	training's auc: 0.895637	training's focal_loss: 0.0015223	valid_1's auc: 0.854208	valid_1's focal_loss: 0.00166873
# [640]	training's auc: 0.896697	training's focal_loss: 0.00151748	valid_1's auc: 0.854328	valid_1's focal_loss: 0.00166845
# [660]	training's auc: 0.897692	training's focal_loss: 0.00151292	valid_1's auc: 0.854392	valid_1's focal_loss: 0.00166832
# [680]	training's auc: 0.898643	training's focal_loss: 0.00150865	valid_1's auc: 0.854457	valid_1's focal_loss: 0.00166818
# [700]	training's auc: 0.89957	training's focal_loss: 0.0015044	valid_1's auc: 0.854524	valid_1's focal_loss: 0.00166799
# [720]	training's auc: 0.900524	training's focal_loss: 0.00149995	valid_1's auc: 0.854639	valid_1's focal_loss: 0.00166769
# [740]	training's auc: 0.901511	training's focal_loss: 0.00149549	valid_1's auc: 0.854679	valid_1's focal_loss: 0.00166766
# [760]	training's auc: 0.902361	training's focal_loss: 0.00149145	valid_1's auc: 0.854718	valid_1's focal_loss: 0.0016677
# [780]	training's auc: 0.903305	training's focal_loss: 0.00148713	valid_1's auc: 0.854776	valid_1's focal_loss: 0.00166763
# [800]	training's auc: 0.904221	training's focal_loss: 0.00148294	valid_1's auc: 0.854891	valid_1's focal_loss: 0.00166728
# [820]	training's auc: 0.905098	training's focal_loss: 0.00147882	valid_1's auc: 0.854982	valid_1's focal_loss: 0.00166705
# [840]	training's auc: 0.905918	training's focal_loss: 0.00147498	valid_1's auc: 0.855001	valid_1's focal_loss: 0.00166719
# [860]	training's auc: 0.906746	training's focal_loss: 0.001471	valid_1's auc: 0.854973	valid_1's focal_loss: 0.00166749
# [880]	training's auc: 0.907593	training's focal_loss: 0.00146703	valid_1's auc: 0.854974	valid_1's focal_loss: 0.00166763
# [900]	training's auc: 0.908408	training's focal_loss: 0.00146312	valid_1's auc: 0.855008	valid_1's focal_loss: 0.00166772
# [920]	training's auc: 0.909179	training's focal_loss: 0.00145946	valid_1's auc: 0.855022	valid_1's focal_loss: 0.00166786
# Early stopping, best iteration is:
# [822]	training's auc: 0.905163	training's focal_loss: 0.00147852	valid_1's auc: 0.854989	valid_1's focal_loss: 0.00166703
# #######################
# [0.49764863 0.50825391 0.4877179  ... 0.43882666 0.43505161 0.40871996]
# CV AUC scores:  []
# Maximum CV AUC score:  nan
# CV AUC scores:  [0.8538158376788763, 0.8550102315670481, 0.8591967027948344, 0.8586888038357473, 0.8549892466206295]
# Maximum CV AUC score:  0.8563401644994271
# CPU times: user 1h 22min 3s, sys: 24.3 s, total: 1h 22min 27s
# Wall time: 48min 7s

# %%
class VotingModel(BaseEstimator, RegressorMixin):
    def __init__(self, estimators):
        super().__init__()
        self.estimators = estimators
        
    def fit(self, X, y=None):
        return self
    
    def predict(self, X):
        y_preds = [estimator.predict(X) for estimator in self.estimators]
        return np.mean(y_preds, axis=0)
    
    def predict_proba(self, X):        
        y_preds = [estimator.predict_proba(X)[:,1] for estimator in self.estimators[:5]]
       
        X[cat_cols] = X[cat_cols].astype("category")
        y_preds += [special.expit(estimator.predict_proba(X)) for estimator in self.estimators[5:]]
        print(y_preds)
        print(len(y_preds))
        return np.mean(y_preds, axis=0)

model = VotingModel(fitted_models_cat+fitted_models_lgb)
